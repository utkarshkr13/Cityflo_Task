# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url='https://www.99acres.com/search/property/rent/navi-mumbai?city=15&preference=R&area_unit=1&res_com=R'

# %%
HEADERS = ({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36', 'Accept-Language': 'en-US, en;q=0.5'})

# %%
webpage=requests.get(url,headers=HEADERS)

# %%
type(webpage.content)
# Out:
# bytes

# %%
soup=BeautifulSoup(webpage.content,"html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
links = soup.find_all("a", attrs={'body_med srpTuple__propertyName'})

# %%
links
# Out:
# [<a class="body_med srpTuple__propertyName" href="https://www.99acres.com/3-bhk-bedroom-apartment-flat-for-rent-in-bhoomi-gardenia-2-roadpali-mumbai-navi-800-sq-ft-r1-spid-C69459152" id="srp_tuple_property_title" target="blank"><h2 class="srpTuple__tupleTitleOverflow">3 BHK Flat for rent in Roadpali</h2></a>,
#  <a class="body_med srpTuple__propertyName" href="https://www.99acres.com/1-bhk-bedroom-apartment-flat-for-rent-in-supreme-krishiv-kripa-sector-35d-kharghar-mumbai-navi-670-sq-ft-spid-C71339320" id="srp_tuple_property_title" target="blank"><h2 class="srpTuple__tupleTitleOverflow">1 BHK Flat for rent in Sector 35D Kharghar</h2></a>,
#  <a class="body_med srpTuple__propertyName" href="https://www.99acres.com/3-bhk-bedroom-apartment-flat-for-rent-in-sector-28-vashi-mumbai-navi-1100-sq-ft-spid-P70530510" id="srp_tuple_property_title" target="blank"><h2 class="srpTuple__tupleTitleOverflow">3 BHK Flat for rent in Sector 28 Vashi</h2></a>,
# ...

# %%
house_list = links[0].get('href')

# %%
house_list
# Out:
# 'https://www.99acres.com/3-bhk-bedroom-apartment-flat-for-rent-in-bhoomi-gardenia-2-roadpali-mumbai-navi-800-sq-ft-r1-spid-C69459152'

# %%
new_webpage=requests.get(house_list,headers=HEADERS)

# %%
new_webpage
# Out:
# <Response [200]>

# %%
new_soup=BeautifulSoup(new_webpage.content,"html.parser")

# %%
new_soup
# Out:
# <!DOCTYPE html>
# ...

# %%
new_soup.find("span", attrs={"class":'component__pdPropValue'}).text.strip()
# Out:
# '21,000'

# %%
a=new_soup.find("span", attrs={"class":'component__pdPropDetail2Heading'}).text.strip()
a[0:4]
# Out:
# '3BHK'

# %%
new_soup.find("span", attrs={"id":'carpetArea_span'}).text
# Out:
# '800'

# %%
b=new_soup.find("span", attrs={"class":'component__pdPropAddress'}).text.strip().split()
b[-4][0:-1]
# Out:
# 'Roadpali'

# %%
b[-3]+' '+b[-2]
# Out:
# 'Navi Mumbai,'
